# %% [markdown]
# <a href="https://colab.research.google.com/github/Linkforce1/sumer-shrinebowl-2026-analytics/blob/main/Exploratory_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
